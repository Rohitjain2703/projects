# %% [markdown]
# # Decisin trees project

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv("Downloads\penguins_size.csv")
ds.head(50)
# Out:
#    species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen              39.1             18.7              181.0
# 1   Adelie  Torgersen              39.5             17.4              186.0
# 2   Adelie  Torgersen              40.3             18.0              195.0
# 3   Adelie  Torgersen               NaN              NaN                NaN
# 4   Adelie  Torgersen              36.7             19.3              193.0
# 5   Adelie  Torgersen              39.3             20.6              190.0
# 6   Adelie  Torgersen              38.9             17.8              181.0
# 7   Adelie  Torgersen              39.2             19.6              195.0
# 8   Adelie  Torgersen              34.1             18.1              193.0
# 9   Adelie  Torgersen              42.0             20.2              190.0
# 10  Adelie  Torgersen              37.8             17.1              186.0
# 11  Adelie  Torgersen              37.8             17.3              180.0
# 12  Adelie  Torgersen              41.1             17.6              182.0
# 13  Adelie  Torgersen              38.6             21.2              191.0
# 14  Adelie  Torgersen              34.6             21.1              198.0
# 15  Adelie  Torgersen              36.6             17.8              185.0
# 16  Adelie  Torgersen              38.7             19.0              195.0
# 17  Adelie  Torgersen              42.5             20.7              197.0
# 18  Adelie  Torgersen              34.4             18.4              184.0
# 19  Adelie  Torgersen              46.0             21.5              194.0
# 20  Adelie     Biscoe              37.8             18.3              174.0
# 21  Adelie     Biscoe              37.7             18.7              180.0
# 22  Adelie     Biscoe              35.9             19.2              189.0
# 23  Adelie     Biscoe              38.2             18.1              185.0
# 24  Adelie     Biscoe              38.8             17.2              180.0
# 25  Adelie     Biscoe              35.3             18.9              187.0
# 26  Adelie     Biscoe              40.6             18.6              183.0
# 27  Adelie     Biscoe              40.5             17.9              187.0
# 28  Adelie     Biscoe              37.9             18.6              172.0
# 29  Adelie     Biscoe              40.5             18.9              180.0
# 30  Adelie      Dream              39.5             16.7              178.0
# 31  Adelie      Dream              37.2             18.1              178.0
# 32  Adelie      Dream              39.5             17.8              188.0
# 33  Adelie      Dream              40.9             18.9              184.0
# 34  Adelie      Dream              36.4             17.0              195.0
# 35  Adelie      Dream              39.2             21.1              196.0
# 36  Adelie      Dream              38.8             20.0              190.0
# 37  Adelie      Dream              42.2             18.5              180.0
# 38  Adelie      Dream              37.6             19.3              181.0
# 39  Adelie      Dream              39.8             19.1              184.0
# 40  Adelie      Dream              36.5             18.0              182.0
# 41  Adelie      Dream              40.8             18.4              195.0
# 42  Adelie      Dream              36.0             18.5              186.0
# 43  Adelie      Dream              44.1             19.7              196.0
# 44  Adelie      Dream              37.0             16.9              185.0
# 45  Adelie      Dream              39.6             18.8              190.0
# 46  Adelie      Dream              41.1             19.0              182.0
# 47  Adelie      Dream              37.5             18.9              179.0
# 48  Adelie      Dream              36.0             17.9              190.0
# 49  Adelie      Dream              42.3             21.2              191.0
#
#     body_mass_g     sex
# 0        3750.0    MALE
# 1        3800.0  FEMALE
# 2        3250.0  FEMALE
# 3           NaN     NaN
# 4        3450.0  FEMALE
# 5        3650.0    MALE
# 6        3625.0  FEMALE
# 7        4675.0    MALE
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  FEMALE
# 13       3800.0    MALE
# 14       4400.0    MALE
# 15       3700.0  FEMALE
# 16       3450.0  FEMALE
# 17       4500.0    MALE
# 18       3325.0  FEMALE
# 19       4200.0    MALE
# 20       3400.0  FEMALE
# 21       3600.0    MALE
# 22       3800.0  FEMALE
# 23       3950.0    MALE
# 24       3800.0    MALE
# 25       3800.0  FEMALE
# 26       3550.0    MALE
# 27       3200.0  FEMALE
# 28       3150.0  FEMALE
# 29       3950.0    MALE
# 30       3250.0  FEMALE
# 31       3900.0    MALE
# 32       3300.0  FEMALE
# 33       3900.0    MALE
# 34       3325.0  FEMALE
# 35       4150.0    MALE
# 36       3950.0    MALE
# 37       3550.0  FEMALE
# 38       3300.0  FEMALE
# 39       4650.0    MALE
# 40       3150.0  FEMALE
# 41       3900.0    MALE
# 42       3100.0  FEMALE
# 43       4400.0    MALE
# 44       3000.0  FEMALE
# 45       4600.0    MALE
# 46       3425.0    MALE
# 47       2975.0     NaN
# 48       3450.0  FEMALE
# 49       4150.0    MALE

# %%
ds.tail(50)
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 294  Gentoo  Biscoe              46.4             15.0              216.0
# 295  Gentoo  Biscoe              48.6             16.0              230.0
# 296  Gentoo  Biscoe              47.5             14.2              209.0
# 297  Gentoo  Biscoe              51.1             16.3              220.0
# 298  Gentoo  Biscoe              45.2             13.8              215.0
# 299  Gentoo  Biscoe              45.2             16.4              223.0
# 300  Gentoo  Biscoe              49.1             14.5              212.0
# 301  Gentoo  Biscoe              52.5             15.6              221.0
# 302  Gentoo  Biscoe              47.4             14.6              212.0
# 303  Gentoo  Biscoe              50.0             15.9              224.0
# 304  Gentoo  Biscoe              44.9             13.8              212.0
# 305  Gentoo  Biscoe              50.8             17.3              228.0
# 306  Gentoo  Biscoe              43.4             14.4              218.0
# 307  Gentoo  Biscoe              51.3             14.2              218.0
# 308  Gentoo  Biscoe              47.5             14.0              212.0
# 309  Gentoo  Biscoe              52.1             17.0              230.0
# 310  Gentoo  Biscoe              47.5             15.0              218.0
# 311  Gentoo  Biscoe              52.2             17.1              228.0
# 312  Gentoo  Biscoe              45.5             14.5              212.0
# 313  Gentoo  Biscoe              49.5             16.1              224.0
# 314  Gentoo  Biscoe              44.5             14.7              214.0
# 315  Gentoo  Biscoe              50.8             15.7              226.0
# 316  Gentoo  Biscoe              49.4             15.8              216.0
# 317  Gentoo  Biscoe              46.9             14.6              222.0
# 318  Gentoo  Biscoe              48.4             14.4              203.0
# 319  Gentoo  Biscoe              51.1             16.5              225.0
# 320  Gentoo  Biscoe              48.5             15.0              219.0
# 321  Gentoo  Biscoe              55.9             17.0              228.0
# 322  Gentoo  Biscoe              47.2             15.5              215.0
# 323  Gentoo  Biscoe              49.1             15.0              228.0
# 324  Gentoo  Biscoe              47.3             13.8              216.0
# 325  Gentoo  Biscoe              46.8             16.1              215.0
# 326  Gentoo  Biscoe              41.7             14.7              210.0
# 327  Gentoo  Biscoe              53.4             15.8              219.0
# 328  Gentoo  Biscoe              43.3             14.0              208.0
# 329  Gentoo  Biscoe              48.1             15.1              209.0
# 330  Gentoo  Biscoe              50.5             15.2              216.0
# 331  Gentoo  Biscoe              49.8             15.9              229.0
# 332  Gentoo  Biscoe              43.5             15.2              213.0
# 333  Gentoo  Biscoe              51.5             16.3              230.0
# 334  Gentoo  Biscoe              46.2             14.1              217.0
# 335  Gentoo  Biscoe              55.1             16.0              230.0
# 336  Gentoo  Biscoe              44.5             15.7              217.0
# 337  Gentoo  Biscoe              48.8             16.2              222.0
# 338  Gentoo  Biscoe              47.2             13.7              214.0
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 294       4700.0  FEMALE
# 295       5800.0    MALE
# 296       4600.0  FEMALE
# 297       6000.0    MALE
# 298       4750.0  FEMALE
# 299       5950.0    MALE
# 300       4625.0  FEMALE
# 301       5450.0    MALE
# 302       4725.0  FEMALE
# 303       5350.0    MALE
# 304       4750.0  FEMALE
# 305       5600.0    MALE
# 306       4600.0  FEMALE
# 307       5300.0    MALE
# 308       4875.0  FEMALE
# 309       5550.0    MALE
# 310       4950.0  FEMALE
# 311       5400.0    MALE
# 312       4750.0  FEMALE
# 313       5650.0    MALE
# 314       4850.0  FEMALE
# 315       5200.0    MALE
# 316       4925.0    MALE
# 317       4875.0  FEMALE
# 318       4625.0  FEMALE
# 319       5250.0    MALE
# 320       4850.0  FEMALE
# 321       5600.0    MALE
# 322       4975.0  FEMALE
# 323       5500.0    MALE
# 324       4725.0     NaN
# 325       5500.0    MALE
# 326       4700.0  FEMALE
# 327       5500.0    MALE
# 328       4575.0  FEMALE
# 329       5500.0    MALE
# 330       5000.0  FEMALE
# 331       5950.0    MALE
# 332       4650.0  FEMALE
# 333       5500.0    MALE
# 334       4375.0  FEMALE
# 335       5850.0    MALE
# 336       4875.0       .
# 337       6000.0    MALE
# 338       4925.0  FEMALE
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
ds["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
ds["sex"].unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %%
ds["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
ds["species"].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
ds["island"].value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
ds["sex"].value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
ds.shape
# Out:
# (344, 7)

# %%
ds=ds[ds["sex"]!="."]
ds.shape
# Out:
# (343, 7)

# %%
sns.scatterplot(x="culmen_length_mm",y="culmen_depth_mm",hue="species",data=ds)
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.pairplot(ds,hue="species")

# %%
sns.catplot(x="species",y="culmen_length_mm",data=ds,kind="bar",col="sex")

# %%
#feature engineering 
ds.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
ds=ds.dropna()
ds.shape
# Out:
# (333, 7)

# %%
#encoding 
pd.get_dummies(ds.drop("species",axis=1),drop_first=True)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# 1               0                 1         0
# 2               0                 1         0
# 4               0                 1         0
# 5               0                 1         1
# ..            ...               ...       ...
# 338             0                 0         0
# 340             0                 0         0
# 341             0                 0         1
# 342             0                 0         0
# 343             0                 0         1
#
# [333 rows x 7 columns]

# %%
x=pd.get_dummies(ds.drop("species",axis=1),drop_first=True)

# %%
y=ds["species"]

# %%
#train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
#modelling with defult parameter decision 
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#prediction 
test_pred=model.predict(x_test)
train_pred=model.predict(x_train)

# %%
#evaluation 
from sklearn.metrics import classification_report,plot_confusion_matrix,accuracy_score

print(accuracy_score(y_train,train_pred))
accuracy_score(y_test,test_pred)
# Out:
# 1.0
# 0.96

# %%
plot_confusion_matrix(model,x_test,y_test)
plt.show()
# Out:
# C:\Users\Rohit Jain\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.95      0.95        40
#    Chinstrap       0.93      0.96      0.95        27
#       Gentoo       1.00      0.97      0.98        33
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100

# %% [markdown]
# # model importance is showing the best feature/coumns high impotances choes the in decision

# %%
model.feature_importances_
# Out:
# array([0.33350103, 0.02010577, 0.57575804, 0.        , 0.04491847,
#        0.        , 0.02571668])

# %%
pd.DataFrame(index=x.columns,data=model.feature_importances_,columns=["FeatureImportances"])
# Out:
#                    FeatureImportances
# culmen_length_mm             0.333501
# culmen_depth_mm              0.020106
# flipper_length_mm            0.575758
# body_mass_g                  0.000000
# island_Dream                 0.044918
# island_Torgersen             0.000000
# sex_MALE                     0.025717

# %% [markdown]
# # visualize the trees

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(12,10),dpi=500)
plot_tree(model,filled=True,feature_names=x.columns)
plt.show()

# %% [markdown]
# # optimization --pruning of decision tree pruning mean cutting uneseeracy part of tree

# %%
pruned_tree=DecisionTreeClassifier(max_depth=2)

# %%
def report_model(model):
    model.fit(x_train,y_train)
    train_pred=model.predict(x_train)
    test_pred=model.predict(x_test)
    print(accuracy_score(y_train,train_pred))
    print(accuracy_score(y_test,test_pred))
    plt.figure(figsize=(12,12),dpi=150)
    plot_tree(model,filled=True,feature_names=x.columns)

# %%
report_model(pruned_tree)
# Out:
# 0.9699570815450643
# 0.92

# %% [markdown]
# # max leaf nodes

# %%
pruned_tree=DecisionTreeClassifier(max_leaf_nodes=3)

# %%
report_model(pruned_tree)
# Out:
# 0.9656652360515021
# 0.91

# %% [markdown]
# # using hyper paramer tunning

# %%
from sklearn.model_selection import GridSearchCV

estimator=DecisionTreeClassifier()

param_grid={"min_samples_split":[1,2,3,4],"min_samples_leaf":[1,2,3,4],"max_depth":[1,2,3,4],"criterion":["gini","entropy"]}

#"min_samples_split":[1,2,3,4],"min_samples_leaf":[1,2,3,4],"max_depth":[1,2,3,4],"criterion":["gini","entropy"]}
#"min_samples_split":list(range(1,10)),"criterion":["gini","entropy"]}

grid=GridSearchCV(estimator,param_grid,cv=5,scoring="accuracy")

grid.fit(x,y)
# Out:
# C:\Users\Rohit Jain\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 160 fits failed out of a total of 640.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Rohit Jain\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Rohit Jain\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Rohit Jain\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Rohit Jain\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.78371777 0.78371777 0.78371777        nan 0.78371777
#  0.78371777 0.78371777        nan 0.78371777 0.78371777 0.78371777
#         nan 0.78371777 0.78371777 0.78371777        nan 0.95187698
#  0.95187698 0.95187698        nan 0.95187698 0.95187698 0.95187698
#         nan 0.95187698 0.95187698 0.95187698        nan 0.95187698
#  0.95187698 0.95187698        nan 0.96693804 0.96390773 0.96693804
#         nan 0.96390773 0.96087743 0.96390773        nan 0.96390773
#  0.96390773 0.96390773        nan 0.94292175 0.94292175 0.94292175
#         nan 0.96983265 0.96684758 0.96684758        nan 0.97892356
#  0.96987788 0.96987788        nan 0.97589326 0.97589326 0.97290819
#         nan 0.94898236 0.95196744 0.94898236        nan 0.78371777
#  0.78371777 0.78371777        nan 0.78371777 0.78371777 0.78371777
#         nan 0.78371777 0.78371777 0.78371777        nan 0.78371777
#  0.78371777 0.78371777        nan 0.94590683 0.94590683 0.94590683
#         nan 0.94590683 0.94590683 0.94590683        nan 0.94590683
#  0.94590683 0.94590683        nan 0.94590683 0.94590683 0.94590683
#         nan 0.96386251 0.96386251 0.96689281        nan 0.96689281
#  0.96689281 0.96689281        nan 0.96689281 0.96689281 0.96689281
#         nan 0.9608322  0.9608322  0.9608322         nan 0.97584803
#  0.97584803 0.97887834        nan 0.97892356 0.97589326 0.97286296
#         nan 0.97892356 0.97589326 0.97589326        nan 0.97286296
#  0.97589326 0.97286296]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [1, 2, 3, 4]},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2}

# %% [markdown]
# # rebuild model with hyper paramer tuning with best value

# %%
d_model=DecisionTreeClassifier(criterion='entropy',
 max_depth= 4,
 min_samples_leaf=1,
 min_samples_split=4)
    

#criterion="entropy",min_samples_split=3


d_model.fit(x_train,y_train)

train_pred=d_model.predict(x_train)
test_pred=d_model.predict(x_test)

print(accuracy_score(y_train,train_pred))
print(accuracy_score(y_test,test_pred))
# Out:
# 0.9914163090128756
# 0.93

# %%
d_model.predict([[119,223,19,3233,33,44,443]])
# Out:
# C:\Users\Rohit Jain\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Chinstrap'], dtype=object)
